# %% [markdown]
# # Electric Vehicle Data Analysis and Visualization Milestone 2

# %% [markdown]
# First source of data, that I have collected, is from the below website which shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).
#
# https://data.wa.gov/Transportation/Electric-Vehicle-Population-Data/f6w7-q2d2
#
# https://catalog.data.gov/dataset/electric-vehicle-population-data/resource/fa51be35-691f-45d2-9f3e-535877965e69?inner_span=True

# %%
import pandas as pd
df = pd.read_csv("Electric_Vehicle_Population_Data.csv")
df.head(5)
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     BOLT EV          Battery Electric Vehicle (BEV)
# 4      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              42
# 1           Clean Alternative Fuel Vehicle Eligible              38
# 2           Clean Alternative Fuel Vehicle Eligible              73
# 3           Clean Alternative Fuel Vehicle Eligible             238
# 4             Not eligible due to low battery range              26
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                   NaN       198968248
# 1          0                   NaN         5204412
# 2          0                  15.0       218972519
# 3          0                  39.0       186750406
# 4          0                  38.0         2006714
#
#               Vehicle Location        Electric Utility  2020 Census Tract
# 0    POINT (-81.80023 24.5545)                     NaN        12087972100
# 1  POINT (-114.57245 35.16815)                     NaN        32003005702
# 2  POINT (-120.50721 46.60448)              PACIFICORP        53077001602
# 3   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC        53057951101
# 4  POINT (-122.20596 47.97659)  PUGET SOUND ENERGY INC        53061041500

# %%
df.shape
# Out:
# (112634, 17)

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                            int64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# 2020 Census Tract                                      int64
# dtype: object

# %% [markdown]
# # Step1 : Lets update the header and data for Electric Vehicle Type

# %%
#lets check the vechicle types first
df[['Electric Vehicle Type']].value_counts()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            86044
# Plug-in Hybrid Electric Vehicle (PHEV)    26590
# dtype: int64

# %%
def vehicle_type(row):
    if row == 'Battery Electric Vehicle (BEV)':
        return 'BEV'
    if row == 'Plug-in Hybrid Electric Vehicle (PHEV)':
        return 'PHEV'
    
df['Vehicle Type'] = df['Electric Vehicle Type'].apply(lambda row: vehicle_type(row))
df = df.drop('Electric Vehicle Type', axis=1)
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# 0  RAV4 PRIME           Clean Alternative Fuel Vehicle Eligible
# 1        VOLT           Clean Alternative Fuel Vehicle Eligible
# 2        LEAF           Clean Alternative Fuel Vehicle Eligible
# 3     BOLT EV           Clean Alternative Fuel Vehicle Eligible
# 4      FUSION             Not eligible due to low battery range
#
#    Electric Range  Base MSRP  Legislative District  DOL Vehicle ID  \
# 0              42          0                   NaN       198968248
# 1              38          0                   NaN         5204412
# 2              73          0                  15.0       218972519
# 3             238          0                  39.0       186750406
# 4              26          0                  38.0         2006714
#
#               Vehicle Location        Electric Utility  2020 Census Tract  \
# 0    POINT (-81.80023 24.5545)                     NaN        12087972100
# 1  POINT (-114.57245 35.16815)                     NaN        32003005702
# 2  POINT (-120.50721 46.60448)              PACIFICORP        53077001602
# 3   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC        53057951101
# 4  POINT (-122.20596 47.97659)  PUGET SOUND ENERGY INC        53061041500
#
#   Vehicle Type
# 0         PHEV
# 1         PHEV
# 2          BEV
# 3          BEV
# 4         PHEV

# %% [markdown]
# # Step2: Lets update the column name and data for Clean Alternative Fuel Vehicle (CAFV) Eligibility

# %%
#lets check the vechicle types first
df[['Clean Alternative Fuel Vehicle (CAFV) Eligibility']].value_counts()
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Clean Alternative Fuel Vehicle Eligible                         58639
# Eligibility unknown as battery range has not been researched    39236
# Not eligible due to low battery range                           14759
# dtype: int64

# %%
def cafv_eligibility(row):
    if row == 'Clean Alternative Fuel Vehicle Eligible':
        return 'Eligible'
    if row == 'Eligibility unknown as battery range has not been researched':
        return 'Unknown'
    if row == 'Not eligible due to low battery range':
        return 'Not Eligible'
    
df['CAFV Eligibility'] = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].apply(lambda row: cafv_eligibility(row))
df = df.drop('Clean Alternative Fuel Vehicle (CAFV) Eligibility', axis=1)
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model  Electric Range  Base MSRP  Legislative District  \
# 0  RAV4 PRIME              42          0                   NaN
# 1        VOLT              38          0                   NaN
# 2        LEAF              73          0                  15.0
# 3     BOLT EV             238          0                  39.0
# 4      FUSION              26          0                  38.0
#
#    DOL Vehicle ID             Vehicle Location        Electric Utility  \
# 0       198968248    POINT (-81.80023 24.5545)                     NaN
# 1         5204412  POINT (-114.57245 35.16815)                     NaN
# 2       218972519  POINT (-120.50721 46.60448)              PACIFICORP
# 3       186750406   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC
# 4         2006714  POINT (-122.20596 47.97659)  PUGET SOUND ENERGY INC
#
#    2020 Census Tract Vehicle Type CAFV Eligibility
# 0        12087972100         PHEV         Eligible
# 1        32003005702         PHEV         Eligible
# 2        53077001602          BEV         Eligible
# 3        53057951101          BEV         Eligible
# 4        53061041500         PHEV     Not Eligible

# %% [markdown]
# # Step3: Transformation on Electric Range, here lets create an Electric Range Category based on Electric Range.

# %%
df['Electric Range'].plot(kind='hist', edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def electric_range(row):
    if row < 100:
        return 'Low'
    elif row <= 250:
        return 'Mid'
    else:
        return 'High'
    
df['Electric Range Category'] = df['Electric Range'].apply(lambda row: electric_range(row))
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model  Electric Range  Base MSRP  Legislative District  \
# 0  RAV4 PRIME              42          0                   NaN
# 1        VOLT              38          0                   NaN
# 2        LEAF              73          0                  15.0
# 3     BOLT EV             238          0                  39.0
# 4      FUSION              26          0                  38.0
#
#    DOL Vehicle ID             Vehicle Location        Electric Utility  \
# 0       198968248    POINT (-81.80023 24.5545)                     NaN
# 1         5204412  POINT (-114.57245 35.16815)                     NaN
# 2       218972519  POINT (-120.50721 46.60448)              PACIFICORP
# 3       186750406   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC
# 4         2006714  POINT (-122.20596 47.97659)  PUGET SOUND ENERGY INC
#
#    2020 Census Tract Vehicle Type CAFV Eligibility Electric Range Category
# 0        12087972100         PHEV         Eligible                     Low
# 1        32003005702         PHEV         Eligible                     Low
# 2        53077001602          BEV         Eligible                     Low
# 3        53057951101          BEV         Eligible                     Mid
# 4        53061041500         PHEV     Not Eligible                     Low

# %% [markdown]
# # Step4 : Data Cleaning, lets do some cleaning on the Legislative District

# %%
df[['Legislative District']].isnull().sum() 
#There are 286 records for which Legislative District are missing, because those data belong to other state.
# Out:
# Legislative District    286
# dtype: int64

# %%
#Here are the missing percentage of 
df[df['State'].isin(['WA'])].isnull().sum()
# Out:
# VIN (1-10)                   0
# County                       0
# City                         0
# State                        0
# Postal Code                  0
# Model Year                   0
# Make                         0
# Model                       20
# Electric Range               0
# Base MSRP                    0
# Legislative District         0
# DOL Vehicle ID               0
# Vehicle Location            19
# Electric Utility           157
# 2020 Census Tract            0
# Vehicle Type                 0
# CAFV Eligibility             0
# Electric Range Category      0
# dtype: int64

# %%
df[df['State'].isin(['WA'])].shape[0]
# Out:
# 112348

# %%
#Lets delete these records where the state is different then Washington State, as this is like outlier to the actual source, 
#there are very few cars those are being registered from washington state for other state.

# %%
df = df[df['State'].isin(['WA'])]

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                   0
# County                       0
# City                         0
# State                        0
# Postal Code                  0
# Model Year                   0
# Make                         0
# Model                       20
# Electric Range               0
# Base MSRP                    0
# Legislative District         0
# DOL Vehicle ID               0
# Vehicle Location            19
# Electric Utility           157
# 2020 Census Tract            0
# Vehicle Type                 0
# CAFV Eligibility             0
# Electric Range Category      0
# dtype: int64

# %% [markdown]
# # Step5 : Lets eleminate records where Model is missing and Electric Utility is missing

# %%
df = df.dropna(axis = 0)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                 0
# County                     0
# City                       0
# State                      0
# Postal Code                0
# Model Year                 0
# Make                       0
# Model                      0
# Electric Range             0
# Base MSRP                  0
# Legislative District       0
# DOL Vehicle ID             0
# Vehicle Location           0
# Electric Utility           0
# 2020 Census Tract          0
# Vehicle Type               0
# CAFV Eligibility           0
# Electric Range Category    0
# dtype: int64

# %% [markdown]
# # Step 6: Analysis on base price

# %%
df['Base MSRP'].plot(kind='hist', edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print(df['Base MSRP'].max(),df['Base MSRP'].min())
# Out:
# 845000 0

# %%
df[['Base MSRP']].value_counts()
# Out:
# Base MSRP
# 0            108654
# 69900          1493
# 31950           406
# 52900           213
# 32250           158
# 54950           135
# 59900           134
# 39995           118
# 36900           100
# 44100            95
# 64950            82
# 33950            78
# 45600            76
# 52650            67
# 34995            58
# 36800            50
# 55700            47
# 53400            28
# 110950           24
# 98950            23
# 81100            19
# 102000           19
# 90700            18
# 75095            16
# 184400           12
# 43700            10
# 89100             7
# 109000            7
# 91250             4
# 845000            1
# dtype: int64

# %%
df.loc[df['Base MSRP'] == 845000].head()
#High range for this record is due to its brand i.e. PORSCHE.
# Out:
#        VIN (1-10) County         City State  Postal Code  Model Year     Make  \
# 62533  WP0CA2A13F   King  Hunts Point    WA        98004        2015  PORSCHE
#
#       Model  Electric Range  Base MSRP  Legislative District  DOL Vehicle ID  \
# 62533   918              12     845000                  48.0       100479039
#
#                  Vehicle Location  \
# 62533  POINT (-122.1872 47.61001)
#
#                                     Electric Utility  2020 Census Tract  \
# 62533  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)        53033024100
#
#       Vehicle Type CAFV Eligibility Electric Range Category
# 62533         PHEV     Not Eligible                     Low

# %%
print("percentage of vahicles where value is 0 = {}".format(df.loc[df['Base MSRP'] == 0].shape[0]/df.shape[0]))
# Out:
# percentage of vahicles where value is 0 = 0.9688101861759041

# %%
#So lets delete this Base MSRP field as 96% of this is 0
df=df.drop('Base MSRP',axis=1)
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
# 5  5YJ3E1EB5J  Snohomish   Bothell    WA        98021        2018      TESLA
# 6  1N4AZ0CP4D  Snohomish   Everett    WA        98203        2013     NISSAN
#
#      Model  Electric Range  Legislative District  DOL Vehicle ID  \
# 2     LEAF              73                  15.0       218972519
# 3  BOLT EV             238                  39.0       186750406
# 4   FUSION              26                  38.0         2006714
# 5  MODEL 3             215                   1.0       475635324
# 6     LEAF              75                  38.0       253546023
#
#               Vehicle Location        Electric Utility  2020 Census Tract  \
# 2  POINT (-120.50721 46.60448)              PACIFICORP        53077001602
# 3   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC        53057951101
# 4  POINT (-122.20596 47.97659)  PUGET SOUND ENERGY INC        53061041500
# 5   POINT (-122.18384 47.8031)  PUGET SOUND ENERGY INC        53061051916
# 6  POINT (-122.23019 47.94949)  PUGET SOUND ENERGY INC        53061040900
#
#   Vehicle Type CAFV Eligibility Electric Range Category
# 2          BEV         Eligible                     Low
# 3          BEV         Eligible                     Mid
# 4         PHEV     Not Eligible                     Low
# 5          BEV         Eligible                     Mid
# 6          BEV         Eligible                     Low
